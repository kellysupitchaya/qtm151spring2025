# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print("Supitchaya Phongkusonjit")
# Out:
# Supitchaya Phongkusonjit

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by Emory's code of conduct ")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code

fifa23_players = pd.read_csv("data_quiz/fifa23_players_basic.csv")
display(fifa23_players)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# ...                   ...                 ...
# 18534              Medium              Medium
# 18535              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Use queries
#
# <font size = "3">
#
# - Browse the dataset and search for the height variable in cm (centimeters).
#
# - Subset the players whose value of the height variable is above 175 <br>
# and store it in a new dataset
# - How many players are above this height threshold?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. See example provided.

# %%
# Write your own code

# Example: The following code filters whether 
# observations for which `On Loan` is equal to yes
# dataset.query(' `On Loan` == "YES" ')
# Note: be careful with using backward quotations ` here.
# Now apply this to your own example, and calculate the total number of observations.

threshold = 175
height_above_175 = fifa23_players.query("Height(in cm)  > @threshold")

height_above_175 = len(players_above_175)
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[88], line 10
#     height_above_175 = fifa23_players.query("Height(in cm)  > @threshold")
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4823 in query
#     res = self.eval(expr, **kwargs)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4949 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/eval.py:336 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:809 in __init__
#     self.terms = self.parse()
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:828 in parse
#     return self._visitor.visit(self.expr)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:408 in visit
#     raise e
#
#   File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expr.py:404 in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File /opt/anaconda3/lib/python3.12/ast.py:52 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     Height (in cm )>__pd_eval_local_threshold
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# <font size = "5">
#
# (b) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Contract Until" shows the date in which a player's contract will expire.
# - Use ".sort_values()" to order the "Contract Until" column <br>
# from later dates to earlier dates.
# - Get a subset with the 5 players in the dataset <br>
# whose contracts will expire later.
# - From this subset, display the names and year in which the contract will expire.
#
# Your output should look something like this:
#
# | Full Name | Contract Until |
# | -------- | ------- |
# | José Luis García Vayá | 2032
# | José Luis García Vayá | 2032
# | Jon Moncayola Tollar | 2031
# | Jon Moncayloa Tollar | 2031
# | Josip Sutalo | 2028
# | Aurelien Tchouaméni | 2028

# %%
# Write your own code

fifa = fifa23_players.sort_values(by = "Contract Until", ascending = False)
five_players = fifa.iloc[0:5,:]
display(five_players)
# Out:
#       Unnamed: 0   Known As              Full Name  Overall  Potential  \
# 1876        1876     Pepelu  Jose Luís García Vayá       75         81
# 1806        1806     Pepelu  Jose Luís García Vayá       75         81
# 1478        1478  Moncayola   Jon Moncayola Tollar       75         81
# 1523        1523  Moncayola   Jon Moncayola Tollar       75         81
# 1649        1649  J. Šutalo           Josip Šutalo       75         84
#
#       Value(in Euro) Positions Played Best Position Nationality  \
# 1876         9000000           CM,CDM            CM       Spain
# 1806         9000000           CM,CDM            CM       Spain
# 1478         9000000           CM,CDM            CM       Spain
# 1523         9000000           CM,CDM            CM       Spain
# 1649        12000000               CB            CB     Croatia
#
#                                             Image Link  ...  Preferred Foot  \
# 1876  https://cdn.sofifa.net/players/230/786/23_60.png  ...           Right
# 1806  https://cdn.sofifa.net/players/230/786/23_60.png  ...           Right
# 1478  https://cdn.sofifa.net/players/247/495/23_60.png  ...           Right
# 1523  https://cdn.sofifa.net/players/247/495/23_60.png  ...           Right
# 1649  https://cdn.sofifa.net/players/256/325/23_60.png  ...           Right
#
#       Weak Foot Rating  Skill Moves  International Reputation  \
# 1876                 3            3                         1
# 1806                 3            3                         1
# 1478                 4            3                         1
# 1523                 4            3                         1
# 1649                 3            2                         1
#
#       National Team Name             National Team Image Link  \
# 1876                   -  https://cdn.sofifa.net/flags/es.png
# 1806                   -  https://cdn.sofifa.net/flags/es.png
# 1478                   -  https://cdn.sofifa.net/flags/es.png
# 1523                   -  https://cdn.sofifa.net/flags/es.png
# 1649             Croatia  https://cdn.sofifa.net/flags/hr.png
#
#       National Team Position  National Team Jersey Number Attacking Work Rate  \
# 1876                       -                            -              Medium
# 1806                       -                            -              Medium
# 1478                       -                            -              Medium
# 1523                       -                            -              Medium
# 1649                     SUB                            5              Medium
#
#      Defensive Work Rate
# 1876              Medium
# 1806              Medium
# 1478                High
# 1523                High
# 1649                High
#
# [5 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "TotalStats"
# - If "TotalStats > 85", classification = "Top Performer"
# - If "TotalStats <= 85", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "TotalStats" in the dataset <br>
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code

def myfunction(TotalStats):
    if TotalStats > 85:
        classification = "Top Performer"
    elif TotalStats <= 85:
        classification = "Non Top-Performer"
    return classification

player_classification = fifa23_players['TotalStats']

fifa23_players["player_classification"] = fifa23_players["TotalStats"].apply(myfunction)

display(fifa23_players)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Skill Moves  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            4
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...            4
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...            4
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...            4
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...            5
# ...                                                 ...  ...          ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...            2
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...            2
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...            2
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...            2
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 1                             4              France
# 2                             5              Poland
# 3                             4             Belgium
# 4                             4              France
# ...                         ...                 ...
# 18534                         1                   -
# 18535                         1                   -
# 18536                         1                   -
# 18537                         1                   -
# 18538                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 1                              19               Medium               Medium
# 2                               9                 High               Medium
# 3                               7                 High                 High
# 4                              10                 High                  Low
# ...                           ...                  ...                  ...
# 18534                           -               Medium               Medium
# 18535                           -               Medium               Medium
# 18536                           -                 High               Medium
# 18537                           -               Medium               Medium
# 18538                           -               Medium               Medium
#
#       random_var player_classification
# 0       0.842103         Top Performer
# 1       0.544882         Top Performer
# 2       0.351124         Top Performer
# 3       0.115655         Top Performer
# 4       0.093053         Top Performer
# ...          ...                   ...
# 18534   0.834232         Top Performer
# 18535   0.711566         Top Performer
# 18536   0.086672         Top Performer
# 18537   0.899778         Top Performer
# 18538   0.639013         Top Performer
#
# [18539 rows x 35 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Overall" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code

results = smf.ols(formula = '~ ',data = fifa23_players)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'x' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 # Write your own code
# ----> 3 results = smf.ols(formula = ' ~ x',data = fifa23_players)
#
# File /opt/anaconda3/lib/python3.12/site-packages/statsmodels/base/model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File /opt/anaconda3/lib/python3.12/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
#     311 if lhs.shape[1] == 0:
#     312     raise PatsyError("model is missing required outcome variables")
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162 def data_iter_maker():
#     163     return iter([data])
# --> 164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
#     167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/highlevel.py:66, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64 if isinstance(formula_like, ModelDesc):
#      65     assert isinstance(eval_env, EvalEnvironment)
# ---> 66     return design_matrix_builders([formula_like.lhs_termlist,
#      67                                    formula_like.rhs_termlist],
#      68                                   data_iter_maker,
#      69                                   eval_env,
#      70                                   NA_action)
#      71 else:
#      72     return None
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/build.py:693, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     689 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     690 # Now all the factors have working eval methods, so we can evaluate them
#     691 # on some data to find out what type of data they return.
#     692 (num_column_counts,
# --> 693  cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                factor_states,
#     695                                                data_iter_maker,
#     696                                                NA_action)
#     697 # Now we need the factor infos, which encapsulate the knowledge of
#     698 # how to turn any given factor into a chunk of data:
#     699 factor_infos = {}
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/build.py:443, in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441 for data in data_iter_maker():
#     442     for factor in list(examine_needed):
# --> 443         value = factor.eval(factor_states[factor], data)
#     444         if factor in cat_sniffers or guess_categorical(value):
#     445             if factor not in cat_sniffers:
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/eval.py:568, in EvalFactor.eval(self, memorize_state, data)
#     567 def eval(self, memorize_state, data):
# --> 568     return self._eval(memorize_state["eval_code"],
#     569                       memorize_state,
#     570                       data)
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/eval.py:551, in EvalFactor._eval(self, code, memorize_state, data)
#     549 def _eval(self, code, memorize_state, data):
#     550     inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 551     return call_and_wrap_exc("Error evaluating factor",
#     552                              self,
#     553                              memorize_state["eval_env"].eval,
#     554                              code,
#     555                              inner_namespace=inner_namespace)
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39     new_exc = PatsyError("%s: %s: %s"
#      40                          % (msg, e.__class__.__name__, e),
#      41                          origin)
#      42     # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43     exec("raise new_exc from e")
#      44 else:
#      45     # In python 2, we just let the original exception escape -- better
#      46     # than destroying the traceback. But if it's a PatsyError, we can
#      47     # at least set the origin properly.
#      48     if isinstance(e, PatsyError):
#
# File <string>:1
#
# PatsyError: Error evaluating factor: NameError: name 'x' is not defined
#     ~ x
#       ^

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.4```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.4```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code
n = 18539

fifa23_players["random_var"] = np.random.uniform(0, 1, size=n)

data0 = fifa23_players.query("random_var < 0.4")
data1 = fifa23_players.query("random_var >= 0.4")

print(data0)
# Out:
#        Unnamed: 0         Known As           Full Name  Overall  Potential  \
# 2               2   R. Lewandowski  Robert Lewandowski       91         91
# 3               3     K. De Bruyne     Kevin De Bruyne       91         91
# 4               4        K. Mbappé       Kylian Mbappé       91         95
# 7               7         M. Neuer        Manuel Neuer       90         90
# 10             10          H. Kane          Harry Kane       89         89
# ...           ...              ...                 ...      ...        ...
# 18524       18524       A. Brînzea      Andreș Brînzea       48         72
# 18525       18525  J. Russell-Rowe  Jacen Russell-Rowe       48         65
# 18528       18528        Zhang Yue           Yue Zhang       48         56
# 18532       18532         H. Singh   Harmanpreet Singh       48         56
# 18536       18536        L. Mullan         Liam Mullan       47         67
#
#        Value(in Euro) Positions Played Best Position       Nationality  \
# 2            84000000               ST            ST            Poland
# 3           107500000           CM,CAM            CM           Belgium
# 4           190500000            ST,LW            ST            France
# 7            13500000               GK            GK           Germany
# 10          105500000               ST            ST           England
# ...               ...              ...           ...               ...
# 18524          130000               GK            GK           Romania
# 18525          120000               ST           CAM            Canada
# 18528          110000               RM            LM          China PR
# 18532          100000               ST            ST             India
# 18536          130000               CM            RM  Northern Ireland
#
#                                              Image Link  ...  \
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png  ...
# 10     https://cdn.sofifa.net/players/202/126/23_60.png  ...
# ...                                                 ...  ...
# 18524  https://cdn.sofifa.net/players/271/179/23_60.png  ...
# 18525  https://cdn.sofifa.net/players/269/923/23_60.png  ...
# 18528  https://cdn.sofifa.net/players/268/922/23_60.png  ...
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# 7                     4            1                         5
# 10                    5            3                         4
# ...                 ...          ...                       ...
# 18524                 2            1                         1
# 18525                 3            2                         1
# 18528                 2            2                         1
# 18532                 2            2                         1
# 18536                 3            2                         1
#
#        National Team Name                 National Team Image Link  \
# 2                  Poland      https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium      https://cdn.sofifa.net/flags/be.png
# 4                  France      https://cdn.sofifa.net/flags/fr.png
# 7                 Germany      https://cdn.sofifa.net/flags/de.png
# 10                England  https://cdn.sofifa.net/flags/gb-eng.png
# ...                   ...                                      ...
# 18524                   -      https://cdn.sofifa.net/flags/ro.png
# 18525                   -      https://cdn.sofifa.net/flags/ca.png
# 18528                   -                                        -
# 18532                   -                                        -
# 18536                   -                                        -
#
#       National Team Position  National Team Jersey Number  \
# 2                         ST                            9
# 3                         RF                            7
# 4                         ST                           10
# 7                         GK                            1
# 10                        ST                            9
# ...                      ...                          ...
# 18524                      -                            -
# 18525                      -                            -
# 18528                      -                            -
# 18532                      -                            -
# 18536                      -                            -
#
#        Attacking Work Rate Defensive Work Rate random_var
# 2                     High              Medium   0.351124
# 3                     High                High   0.115655
# 4                     High                 Low   0.093053
# 7                   Medium              Medium   0.187714
# 10                    High                High   0.332862
# ...                    ...                 ...        ...
# 18524               Medium              Medium   0.180370
# 18525               Medium              Medium   0.133907
# 18528               Medium              Medium   0.003611
# 18532               Medium                 Low   0.038667
# 18536                 High              Medium   0.086672
#
# [7242 rows x 34 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping scatter plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display a scatter plot of "Potential" vs "Age" for "data0" using <br>
# ```plt.scatter()```
# - Display a scatter plot of "Potential" vs "Age" for "data1" overlapping <br>
# on top of the previous one
# - You will need to add a legend, label the axes, and the title
# - To get full points, plot the scatter plot with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., y = ... , alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" and "y" vectors instead of ```...``` <br>
# (The alpha option sets the transparency of the scatter plot)
#
# Note: The goal of this question is to illustrate that random <br>
# assignment will produce very similar scatter plots for each variable

# %%
# Write your own code

plt.scatter(x= data0["Potential"], y = data0["Age"])
plt.ylabel(Age)
plt.xlabel(Potential)
plt.show()

plt.hist(x= data1["Potential"], y = data1["Age"], alpha = 0.5)
plt.ylabel(Age)
plt.xlabel(Potential)
plt.show()
